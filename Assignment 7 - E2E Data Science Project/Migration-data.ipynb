# %%
import numpy as np           
import pandas as pd           
import matplotlib.pyplot as plt                   
import seaborn as sns
import sys
import os
# Add the parent directory to the Python path
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(parent_dir)
import google_drive as gd

# %%
df_net_migration = gd.load_file('net_migration_by_country.xlsx')
df_happy = gd.load_file('WHRAllYEars.xlsx')

# %%
df_net_migration.head()
# Out:
#   country_name  year  value
# 0        Aruba  1960      0
# 1        Aruba  1961   -569
# 2        Aruba  1962   -609
# 3        Aruba  1963   -646
# 4        Aruba  1964   -684

# %%
df_net_migration.groupby('Country_Name').describe()
# Out:
#                              year                                              \
#                             count    mean        std     min      25%     50%
# country_name
# Afghanistan                  62.0  1990.5  18.041619  1960.0  1975.25  1990.5
# Africa Eastern and Southern  62.0  1990.5  18.041619  1960.0  1975.25  1990.5
# Africa Western and Central   62.0  1990.5  18.041619  1960.0  1975.25  1990.5
# Albania                      62.0  1990.5  18.041619  1960.0  1975.25  1990.5
# Algeria                      62.0  1990.5  18.041619  1960.0  1975.25  1990.5
# ...                           ...     ...        ...     ...      ...     ...
# West Bank and Gaza           62.0  1990.5  18.041619  1960.0  1975.25  1990.5
# World                        62.0  1990.5  18.041619  1960.0  1975.25  1990.5
# Yemen, Rep.                  62.0  1990.5  18.041619  1960.0  1975.25  1990.5
# Zambia                       62.0  1990.5  18.041619  1960.0  1975.25  1990.5
# ...

# %%
len(df_net_migration['Country_Name'].unique())
# Out:
# 266

# %%
len(df_happy['Country_Name'].unique())
# Out:
# 165

# %%
# Get the unique list of countries from the target dataset
target_countries = df_happy['Country_Name'].unique()

# Filter the migration dataset to only include rows with countries in the target list
df_migration_filtered = df_net_migration[df_net_migration['Country_Name'].isin(target_countries)]
df_migration_filtered.head()


len(df_migration_filtered['Country_Name'].unique())
# Out:
# 146

# %%
# Compare what is in the target list but not in the filtered migration dataset
missing_countries = set(target_countries) - set(df_migration_filtered['Country_Name'].unique())
missing_countries
# Out:
# {'Congo (Brazzaville)',
#  'Congo (Kinshasa)',
#  'Egypt',
#  'Gambia',
#  'Hong Kong S.A.R. of China',
#  'Iran',
#  'Ivory Coast',
#  'Kyrgyzstan',
#  'Laos',
#  'Russia',
#  'Slovakia',
#  'Somaliland region',
#  'South Korea',
#  'State of Palestine',
#  'Syria',
#  'Taiwan Province of China',
#  'Türkiye',
#  'Venezuela',
#  'Yemen'}

# %%
# Rename the countries in the migration dataset to match the target dataset
df_net_migration['Country_Name'].replace({
    'Congo, Dem. Rep.': 'Congo (Brazzaville)',
    'Congo, Rep.': 'Congo (Kinshasa)',
    'Egypt, Arab Rep.': 'Egypt',
    'Gambia, The': 'Gambia',
    'Hong Kong SAR, China': 'Hong Kong S.A.R. of China',
    'Iran, Islamic Rep.': 'Iran',
    "Cote d'Ivoire": 'Ivory Coast',
    'Kyrgyz Republic': 'Kyrgyzstan',
    'Lao PDR': 'Laos',
    'Russian Federation': 'Russia',
    'Slovak Republic': 'Slovakia',
    'Somaliland':'Somaliland region',
    'Korea, Rep.': 'South Korea',
    'West Bank and Gaza': 'State of Palestine',
    'Syrian Arab Republic': 'Syria',
    'Turkiye': 'Türkiye',
    'Venezuela, RB': 'Venezuela',
    'Yemen, Rep.': 'Yemen'
}, inplace=True)
# Out:
# /tmp/ipykernel_57939/759325993.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_net_migration['country_name'].replace({

# %%
# Compare what is in the target list but not in the migration dataset
missing_countries = set(target_countries) - set(df_net_migration['Country_Name'].unique())
missing_countries
# Out:
# {'Taiwan Province of China'}

# %%
# Remove all the countries from the df_net_migration dataset that are not in the target list
df_net_migration_filtered = df_net_migration[df_net_migration['Country_Name'].isin(target_countries)]

# Check the number of unique countries in the filtered migration dataset again
len(df_net_migration_filtered['Country_Name'].unique())
# Out:
# 164

# %% [markdown]
# Taiwan not included, so one country less than in happiness report
