# %%
import pandas as pd
prices = pd.read_csv('dc_price_data.csv', sep=';')
prices
# prices.info()
#prices.isnull()
#prices.isnull().sum()
# Out:
#        AuctionSequence  AuctionSequenceCode  PriceSpecification  \
# count              0.0                  0.0                 0.0
# mean               NaN                  NaN                 NaN
# std                NaN                  NaN                 NaN
# min                NaN                  NaN                 NaN
# 25%                NaN                  NaN                 NaN
# 50%                NaN                  NaN                 NaN
# 75%                NaN                  NaN                 NaN
# max                NaN                  NaN                 NaN
#
#        PriceSpecificationNameCode  Exchange
# count                         0.0       0.0
# mean                          NaN       NaN
# std                           NaN       NaN
# min                           NaN       NaN
# 25%                           NaN       NaN
# 50%                           NaN       NaN
# 75%                           NaN       NaN
# ...

# %%
weather = pd.read_csv('dc_rain_data.csv', sep=';')
weather
#weather.info()
# Out:
#        DataProvider    DataSource DateValueCET TimeValueCET  \
# 0      Point Carbon  PointConnect   09/09/2024     05:00:00
# 1      Point Carbon  PointConnect   09/09/2024     05:00:00
# 2      Point Carbon  PointConnect   09/09/2024     05:00:00
# 3      Point Carbon  PointConnect   09/09/2024     05:00:00
# 4      Point Carbon  PointConnect   09/09/2024     05:00:00
# ...             ...           ...          ...          ...
# 79785  Point Carbon  PointConnect   01/01/1981     04:00:00
# 79786  Point Carbon  PointConnect   01/01/1981     04:00:00
# 79787  Point Carbon  PointConnect   01/01/1981     04:00:00
# 79788  Point Carbon  PointConnect   01/01/1981     04:00:00
# 79789  Point Carbon  PointConnect   01/01/1981     04:00:00
#
#       TimeValueUTCOffset                PowerPriceArea  \
# 0                 +02:00              Brazil-Northeast
# 1                 +02:00                  Brazil-South
# 2                 +02:00                  Brazil-North
# ...

# %%
temp = pd.read_csv('dc_temp_data.csv', sep=';')
temp
# Out:
#        Point Carbon  PointConnect  2024-09-10  2024-09-22  18:00:00  +02:00  \
# 0      Point Carbon  PointConnect  2024-09-10  2024-09-22  16:00:00  +02:00
# 1      Point Carbon  PointConnect  2024-09-10  2024-09-22  17:00:00  +02:00
# 2      Point Carbon  PointConnect  2024-09-10  2024-09-22  15:00:00  +02:00
# 3      Point Carbon  PointConnect  2024-09-10  2024-09-22  20:00:00  +02:00
# 4      Point Carbon  PointConnect  2024-09-10  2024-09-22  18:00:00  +02:00
# ...             ...           ...         ...         ...       ...     ...
# 63678  Point Carbon  PointConnect  2024-08-25  2024-09-08  06:00:00  +02:00
# 63679  Point Carbon  PointConnect  2024-08-25  2024-09-08  02:00:00  +02:00
# 63680  Point Carbon  PointConnect  2024-08-25  2024-09-08  00:00:00  +02:00
# 63681  Point Carbon  PointConnect  2024-08-25  2024-09-08  01:00:00  +02:00
# 63682  Point Carbon  PointConnect  2024-08-25  2024-09-07  23:00:00  +02:00
#
# ...
